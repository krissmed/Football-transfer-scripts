# %%
# imports
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("../../Repo/transfer_market_fm_ids.csv")

# Displays top 5 rows
df.head(5)

# Displays whole table
df
# Out:
#             fm_id                                              proof      id  \
# 0      2000044079  https://www.transfermarkt.com/parmanjan-qeyyum...  774057
# 1        23276522  https://www.transfermarkt.com/yihao-zhong/prof...  317154
# 2          717791  https://www.transfermarkt.com/adrian-mierzejew...   16955
# 3        23020963  https://www.transfermarkt.com/po-liang-chen/pr...   69690
# 4        66029641  https://www.transfermarkt.com/chae-min-lim/pro...  260196
# ...           ...                                                ...     ...
# 57735     8427291  http://www.transfermarkt.com.tr/mickael-boully...    5735
# 57736      402564  http://www.transfermarkt.com.tr/jacky-bonnevay...    5061
# 57737      455977  http://www.transfermarkt.com.tr/zafer-tuzun/st...   22416
# 57738    98003827  http://www.transfermarkt.com/xherdan-shaqiri/p...   86792
# 57739      928942  http://www.transfermarkt.com/morten-nordstrand...   23538
#
#                       slug
# ...

# %%
proof = df['proof']

for i in proof:
    tfm_id = i.split("/")
    for j in i:
        counter = 0
        if j == "spieler" or j == "trainer":
            print(counter)
            print(i[counter+1])
            counter += 1
        else:
            counter += 1
